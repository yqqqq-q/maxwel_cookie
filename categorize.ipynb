# %% [markdown]
# # categorize.ipynb
# Break down our results by website category using the [Cloudflare Domain Intelligence API](https://developers.cloudflare.com/api/operations/domain-intelligence-get-multiple-domain-details). This classification method was used by a [previous IMC paper](https://dl.acm.org/doi/pdf/10.1145/3517745.3561418).

# %%
import requests
from dotenv import load_dotenv
import os
import json
import pandas as pd
from pathlib import Path

API_URL = "https://api.cloudflare.com/client/v4/accounts"

# NOTE: Create a .env file in the root directory of the project containing the following variables:
load_dotenv()
ACCOUNT_ID = os.getenv("ACCOUNT_ID")
BEARER_TOKEN = os.getenv("BEARER_TOKEN")

print(f"ACCOUNT_ID: {ACCOUNT_ID}")
print(f"BEARER_TOKEN: {BEARER_TOKEN}")
# Out:
# ACCOUNT_ID: e66df1360bcc8b1778627a7d5ed3b9d8
# BEARER_TOKEN: OR85df5YVJXMpAWdMuDH73BqNzWir4ur1cKEMkFB

# %%
def fetch_domain_data(domains: list[str]) -> dict:
    """
    Sends a GET request to the Cloudflare Domain Intelligence API with a list of domains and returns the parsed JSON response.

    Args:
        domains (list): List of domain names to fetch data for.

    Returns:
        dict: Parsed JSON response from the API.
    """
    url = f"{API_URL}/{ACCOUNT_ID}/intel/domain/bulk"

    # Prepare the query parameters
    params = {
        'domain': domains
    }

    # Set up the headers with the Bearer token
    headers = {
        'Authorization': f"Bearer {BEARER_TOKEN}",
        'Content-Type': 'application/json'
    }

    # Make the GET request
    response = requests.get(url, headers=headers, params=params)

    # Check if the request was successful
    if response.status_code == 200 and response.json()['success']:
        # Parse the response JSON
        result = response.json()['result']
        return result
    else:
        raise RuntimeError(f"Failed to fetch data: {response.status_code}")

def save_to_json(data, filename='categories.json'):
    with open(filename, 'w') as file:
        json.dump(data, file, indent=4)

def read_json(filename='categories.json'):
    with open(filename, 'r') as file:
        return json.load(file)

# %%
# Assuming the file 'differences.csv' is available in the environment
file_path = 'KJ2GW.txt'

domains = []
with open(file_path) as file:
    for line in file:
        domains.append(line.strip())
print(len(domains))
# Out:
# 10000

# %%
BATCH_SIZE = 10
MAX_RETRIES = 10

all_results = read_json()
for i in range(0, len(domains), BATCH_SIZE):
    cached_results = read_json()
    if domains[i] in [result['domain'] for result in cached_results]:
        print(f"Skipping batch: {i+1}-{i+BATCH_SIZE} as it's already cached")
        continue

    print(f"Requesting batch: {i+1}-{i+BATCH_SIZE} out of {len(domains)}")
    batch = domains[i:i+BATCH_SIZE]
    for attempt in range(MAX_RETRIES):
        try:
            result = fetch_domain_data(batch)
            all_results.extend(result)
            save_to_json(all_results)
            break
        except RuntimeError as e:
            print(f"Failed to request batch: {i+1}-{i+BATCH_SIZE} on attempt {attempt+1}. {e}")
            continue
# Out:
# Skipping batch: 1-10 as it's already cached
# Skipping batch: 11-20 as it's already cached
# Skipping batch: 21-30 as it's already cached
# Skipping batch: 31-40 as it's already cached
# Skipping batch: 41-50 as it's already cached
# Skipping batch: 51-60 as it's already cached
# Skipping batch: 61-70 as it's already cached
# Skipping batch: 71-80 as it's already cached
# Skipping batch: 81-90 as it's already cached
# Skipping batch: 91-100 as it's already cached
# Skipping batch: 101-110 as it's already cached
# Skipping batch: 111-120 as it's already cached
# Skipping batch: 121-130 as it's already cached
# Skipping batch: 131-140 as it's already cached
# Skipping batch: 141-150 as it's already cached
# Skipping batch: 151-160 as it's already cached
# Skipping batch: 161-170 as it's already cached
# Skipping batch: 171-180 as it's already cached
# Skipping batch: 181-190 as it's already cached
# Skipping batch: 191-200 as it's already cached
# Skipping batch: 201-210 as it's already cached
# Skipping batch: 211-220 as it's already cached
# Skipping batch: 221-230 as it's already cached
# Skipping batch: 231-240 as it's already cached
# Skipping batch: 241-250 as it's already cached
# Skipping batch: 251-260 as it's already cached
# Skipping batch: 261-270 as it's already cached
# Skipping batch: 271-280 as it's already cached
# Skipping batch: 281-290 as it's already cached
# Skipping batch: 291-300 as it's already cached
# Skipping batch: 301-310 as it's already cached
# Skipping batch: 311-320 as it's already cached
# Skipping batch: 321-330 as it's already cached
# Skipping batch: 331-340 as it's already cached
# Skipping batch: 341-350 as it's already cached
# Skipping batch: 351-360 as it's already cached
# Skipping batch: 361-370 as it's already cached
# Skipping batch: 371-380 as it's already cached
# Skipping batch: 381-390 as it's already cached
# Skipping batch: 391-400 as it's already cached
# Skipping batch: 401-410 as it's already cached
# Skipping batch: 411-420 as it's already cached
# Skipping batch: 421-430 as it's already cached
# Skipping batch: 431-440 as it's already cached
# Skipping batch: 441-450 as it's already cached
# Skipping batch: 451-460 as it's already cached
# Skipping batch: 461-470 as it's already cached
# Skipping batch: 471-480 as it's already cached
# Skipping batch: 481-490 as it's already cached
# Skipping batch: 491-500 as it's already cached
# Skipping batch: 501-510 as it's already cached
# Skipping batch: 511-520 as it's already cached
# Skipping batch: 521-530 as it's already cached
# Skipping batch: 531-540 as it's already cached
# Skipping batch: 541-550 as it's already cached
# Skipping batch: 551-560 as it's already cached
# Skipping batch: 561-570 as it's already cached
# Skipping batch: 571-580 as it's already cached
# Skipping batch: 581-590 as it's already cached
# Skipping batch: 591-600 as it's already cached
# Skipping batch: 601-610 as it's already cached
# Skipping batch: 611-620 as it's already cached
# Skipping batch: 621-630 as it's already cached
# Skipping batch: 631-640 as it's already cached
# Skipping batch: 641-650 as it's already cached
# Skipping batch: 651-660 as it's already cached
# Skipping batch: 661-670 as it's already cached
# Skipping batch: 671-680 as it's already cached
# Skipping batch: 681-690 as it's already cached
# Skipping batch: 691-700 as it's already cached
# Skipping batch: 701-710 as it's already cached
# Skipping batch: 711-720 as it's already cached
# Skipping batch: 721-730 as it's already cached
# Skipping batch: 731-740 as it's already cached
# Skipping batch: 741-750 as it's already cached
# Skipping batch: 751-760 as it's already cached
# Skipping batch: 761-770 as it's already cached
# Skipping batch: 771-780 as it's already cached
# Skipping batch: 781-790 as it's already cached
# Skipping batch: 791-800 as it's already cached
# Skipping batch: 801-810 as it's already cached
# Skipping batch: 811-820 as it's already cached
# Skipping batch: 821-830 as it's already cached
# Skipping batch: 831-840 as it's already cached
# Skipping batch: 841-850 as it's already cached
# Skipping batch: 851-860 as it's already cached
# Skipping batch: 861-870 as it's already cached
# Skipping batch: 871-880 as it's already cached
# Skipping batch: 881-890 as it's already cached
# Skipping batch: 891-900 as it's already cached
# Skipping batch: 901-910 as it's already cached
# Skipping batch: 911-920 as it's already cached
# Skipping batch: 921-930 as it's already cached
# Skipping batch: 931-940 as it's already cached
# Skipping batch: 941-950 as it's already cached
# Skipping batch: 951-960 as it's already cached
# Skipping batch: 961-970 as it's already cached
# Skipping batch: 971-980 as it's already cached
# Skipping batch: 981-990 as it's already cached
# Skipping batch: 991-1000 as it's already cached
# Skipping batch: 1001-1010 as it's already cached
# Skipping batch: 1011-1020 as it's already cached
# Skipping batch: 1021-1030 as it's already cached
# Skipping batch: 1031-1040 as it's already cached
# Skipping batch: 1041-1050 as it's already cached
# Skipping batch: 1051-1060 as it's already cached
# Skipping batch: 1061-1070 as it's already cached
# Skipping batch: 1071-1080 as it's already cached
# Skipping batch: 1081-1090 as it's already cached
# Skipping batch: 1091-1100 as it's already cached
# Skipping batch: 1101-1110 as it's already cached
# Skipping batch: 1111-1120 as it's already cached
# Skipping batch: 1121-1130 as it's already cached
# Skipping batch: 1131-1140 as it's already cached
# Skipping batch: 1141-1150 as it's already cached
# Skipping batch: 1151-1160 as it's already cached
# Skipping batch: 1161-1170 as it's already cached
# Skipping batch: 1171-1180 as it's already cached
# Skipping batch: 1181-1190 as it's already cached
# Skipping batch: 1191-1200 as it's already cached
# Skipping batch: 1201-1210 as it's already cached
# Skipping batch: 1211-1220 as it's already cached
# Skipping batch: 1221-1230 as it's already cached
# Skipping batch: 1231-1240 as it's already cached
# Skipping batch: 1241-1250 as it's already cached
# Skipping batch: 1251-1260 as it's already cached
# Skipping batch: 1261-1270 as it's already cached
# Skipping batch: 1271-1280 as it's already cached
# Skipping batch: 1281-1290 as it's already cached
# Skipping batch: 1291-1300 as it's already cached
# Skipping batch: 1301-1310 as it's already cached
# Skipping batch: 1311-1320 as it's already cached
# Skipping batch: 1321-1330 as it's already cached
# Skipping batch: 1331-1340 as it's already cached
# Skipping batch: 1341-1350 as it's already cached
# Skipping batch: 1351-1360 as it's already cached
# Skipping batch: 1361-1370 as it's already cached
# Skipping batch: 1371-1380 as it's already cached
# Skipping batch: 1381-1390 as it's already cached
# Skipping batch: 1391-1400 as it's already cached
# Skipping batch: 1401-1410 as it's already cached
# Skipping batch: 1411-1420 as it's already cached
# Skipping batch: 1421-1430 as it's already cached
# Skipping batch: 1431-1440 as it's already cached
# Skipping batch: 1441-1450 as it's already cached
# Skipping batch: 1451-1460 as it's already cached
# Skipping batch: 1461-1470 as it's already cached
# Skipping batch: 1471-1480 as it's already cached
# Skipping batch: 1481-1490 as it's already cached
# Skipping batch: 1491-1500 as it's already cached
# Skipping batch: 1501-1510 as it's already cached
# Skipping batch: 1511-1520 as it's already cached
# Skipping batch: 1521-1530 as it's already cached
# Skipping batch: 1531-1540 as it's already cached
# Skipping batch: 1541-1550 as it's already cached
# Skipping batch: 1551-1560 as it's already cached
# Skipping batch: 1561-1570 as it's already cached
# Skipping batch: 1571-1580 as it's already cached
# Skipping batch: 1581-1590 as it's already cached
# Skipping batch: 1591-1600 as it's already cached
# Skipping batch: 1601-1610 as it's already cached
# Skipping batch: 1611-1620 as it's already cached
# Skipping batch: 1621-1630 as it's already cached
# Skipping batch: 1631-1640 as it's already cached
# Skipping batch: 1641-1650 as it's already cached
# Skipping batch: 1651-1660 as it's already cached
# Skipping batch: 1661-1670 as it's already cached
# Skipping batch: 1671-1680 as it's already cached
# Skipping batch: 1681-1690 as it's already cached
# Skipping batch: 1691-1700 as it's already cached
# Skipping batch: 1701-1710 as it's already cached
# Skipping batch: 1711-1720 as it's already cached
# Skipping batch: 1721-1730 as it's already cached
# Skipping batch: 1731-1740 as it's already cached
# Skipping batch: 1741-1750 as it's already cached
# Skipping batch: 1751-1760 as it's already cached
# Skipping batch: 1761-1770 as it's already cached
# Skipping batch: 1771-1780 as it's already cached
# Skipping batch: 1781-1790 as it's already cached
# Skipping batch: 1791-1800 as it's already cached
# Skipping batch: 1801-1810 as it's already cached
# Skipping batch: 1811-1820 as it's already cached
# Skipping batch: 1821-1830 as it's already cached
# Skipping batch: 1831-1840 as it's already cached
# Skipping batch: 1841-1850 as it's already cached
# Skipping batch: 1851-1860 as it's already cached
# Skipping batch: 1861-1870 as it's already cached
# Skipping batch: 1871-1880 as it's already cached
# Skipping batch: 1881-1890 as it's already cached
# Skipping batch: 1891-1900 as it's already cached
# Skipping batch: 1901-1910 as it's already cached
# Skipping batch: 1911-1920 as it's already cached
# Skipping batch: 1921-1930 as it's already cached
# Skipping batch: 1931-1940 as it's already cached
# Skipping batch: 1941-1950 as it's already cached
# Skipping batch: 1951-1960 as it's already cached
# Skipping batch: 1961-1970 as it's already cached
# Skipping batch: 1971-1980 as it's already cached
# Skipping batch: 1981-1990 as it's already cached
# Skipping batch: 1991-2000 as it's already cached
# Skipping batch: 2001-2010 as it's already cached
# Skipping batch: 2011-2020 as it's already cached
# Skipping batch: 2021-2030 as it's already cached
# Skipping batch: 2031-2040 as it's already cached
# Skipping batch: 2041-2050 as it's already cached
# Skipping batch: 2051-2060 as it's already cached
# Skipping batch: 2061-2070 as it's already cached
# Skipping batch: 2071-2080 as it's already cached
# Skipping batch: 2081-2090 as it's already cached
# Skipping batch: 2091-2100 as it's already cached
# Skipping batch: 2101-2110 as it's already cached
# Skipping batch: 2111-2120 as it's already cached
# Skipping batch: 2121-2130 as it's already cached
# Skipping batch: 2131-2140 as it's already cached
# Skipping batch: 2141-2150 as it's already cached
# Skipping batch: 2151-2160 as it's already cached
# Skipping batch: 2161-2170 as it's already cached
# Skipping batch: 2171-2180 as it's already cached
# Skipping batch: 2181-2190 as it's already cached
# Skipping batch: 2191-2200 as it's already cached
# Skipping batch: 2201-2210 as it's already cached
# Skipping batch: 2211-2220 as it's already cached
# Skipping batch: 2221-2230 as it's already cached
# Skipping batch: 2231-2240 as it's already cached
# Skipping batch: 2241-2250 as it's already cached
# Skipping batch: 2251-2260 as it's already cached
# Skipping batch: 2261-2270 as it's already cached
# Skipping batch: 2271-2280 as it's already cached
# Skipping batch: 2281-2290 as it's already cached
# Skipping batch: 2291-2300 as it's already cached
# Skipping batch: 2301-2310 as it's already cached
# Skipping batch: 2311-2320 as it's already cached
# Skipping batch: 2321-2330 as it's already cached
# Skipping batch: 2331-2340 as it's already cached
# Skipping batch: 2341-2350 as it's already cached
# Skipping batch: 2351-2360 as it's already cached
# Skipping batch: 2361-2370 as it's already cached
# Skipping batch: 2371-2380 as it's already cached
# Skipping batch: 2381-2390 as it's already cached
# Skipping batch: 2391-2400 as it's already cached
# Skipping batch: 2401-2410 as it's already cached
# Skipping batch: 2411-2420 as it's already cached
# Skipping batch: 2421-2430 as it's already cached
# Skipping batch: 2431-2440 as it's already cached
# Skipping batch: 2441-2450 as it's already cached
# Skipping batch: 2451-2460 as it's already cached
# Skipping batch: 2461-2470 as it's already cached
# Skipping batch: 2471-2480 as it's already cached
# Skipping batch: 2481-2490 as it's already cached
# Skipping batch: 2491-2500 as it's already cached
# Skipping batch: 2501-2510 as it's already cached
# Skipping batch: 2511-2520 as it's already cached
# Skipping batch: 2521-2530 as it's already cached
# Skipping batch: 2531-2540 as it's already cached
# Skipping batch: 2541-2550 as it's already cached
# Skipping batch: 2551-2560 as it's already cached
# Skipping batch: 2561-2570 as it's already cached
# Skipping batch: 2571-2580 as it's already cached
# Skipping batch: 2581-2590 as it's already cached
# Skipping batch: 2591-2600 as it's already cached
# Skipping batch: 2601-2610 as it's already cached
# Skipping batch: 2611-2620 as it's already cached
# Skipping batch: 2621-2630 as it's already cached
# Skipping batch: 2631-2640 as it's already cached
# Skipping batch: 2641-2650 as it's already cached
# Skipping batch: 2651-2660 as it's already cached
# Skipping batch: 2661-2670 as it's already cached
# Skipping batch: 2671-2680 as it's already cached
# Skipping batch: 2681-2690 as it's already cached
# Skipping batch: 2691-2700 as it's already cached
# Skipping batch: 2701-2710 as it's already cached
# Skipping batch: 2711-2720 as it's already cached
# Skipping batch: 2721-2730 as it's already cached
# Skipping batch: 2731-2740 as it's already cached
# Skipping batch: 2741-2750 as it's already cached
# Skipping batch: 2751-2760 as it's already cached
# Skipping batch: 2761-2770 as it's already cached
# Skipping batch: 2771-2780 as it's already cached
# Skipping batch: 2781-2790 as it's already cached
# Skipping batch: 2791-2800 as it's already cached
# Skipping batch: 2801-2810 as it's already cached
# Skipping batch: 2811-2820 as it's already cached
# Skipping batch: 2821-2830 as it's already cached
# Skipping batch: 2831-2840 as it's already cached
# Skipping batch: 2841-2850 as it's already cached
# Skipping batch: 2851-2860 as it's already cached
# Skipping batch: 2861-2870 as it's already cached
# Skipping batch: 2871-2880 as it's already cached
# Skipping batch: 2881-2890 as it's already cached
# Skipping batch: 2891-2900 as it's already cached
# Skipping batch: 2901-2910 as it's already cached
# Skipping batch: 2911-2920 as it's already cached
# Skipping batch: 2921-2930 as it's already cached
# Skipping batch: 2931-2940 as it's already cached
# Skipping batch: 2941-2950 as it's already cached
# Skipping batch: 2951-2960 as it's already cached
# Skipping batch: 2961-2970 as it's already cached
# Skipping batch: 2971-2980 as it's already cached
# Skipping batch: 2981-2990 as it's already cached
# Skipping batch: 2991-3000 as it's already cached
# Skipping batch: 3001-3010 as it's already cached
# Skipping batch: 3011-3020 as it's already cached
# Skipping batch: 3021-3030 as it's already cached
# Skipping batch: 3031-3040 as it's already cached
# Skipping batch: 3041-3050 as it's already cached
# Skipping batch: 3051-3060 as it's already cached
# Skipping batch: 3061-3070 as it's already cached
# Skipping batch: 3071-3080 as it's already cached
# Skipping batch: 3081-3090 as it's already cached
# Skipping batch: 3091-3100 as it's already cached
# Skipping batch: 3101-3110 as it's already cached
# Skipping batch: 3111-3120 as it's already cached
# Skipping batch: 3121-3130 as it's already cached
# Skipping batch: 3131-3140 as it's already cached
# Skipping batch: 3141-3150 as it's already cached
# Skipping batch: 3151-3160 as it's already cached
# Skipping batch: 3161-3170 as it's already cached
# Skipping batch: 3171-3180 as it's already cached
# Skipping batch: 3181-3190 as it's already cached
# Skipping batch: 3191-3200 as it's already cached
# Skipping batch: 3201-3210 as it's already cached
# Skipping batch: 3211-3220 as it's already cached
# Skipping batch: 3221-3230 as it's already cached
# Skipping batch: 3231-3240 as it's already cached
# Skipping batch: 3241-3250 as it's already cached
# Skipping batch: 3251-3260 as it's already cached
# Skipping batch: 3261-3270 as it's already cached
# Skipping batch: 3271-3280 as it's already cached
# Skipping batch: 3281-3290 as it's already cached
# Skipping batch: 3291-3300 as it's already cached
# Skipping batch: 3301-3310 as it's already cached
# Skipping batch: 3311-3320 as it's already cached
# Skipping batch: 3321-3330 as it's already cached
# Skipping batch: 3331-3340 as it's already cached
# Skipping batch: 3341-3350 as it's already cached
# Skipping batch: 3351-3360 as it's already cached
# Skipping batch: 3361-3370 as it's already cached
# Skipping batch: 3371-3380 as it's already cached
# Skipping batch: 3381-3390 as it's already cached
# Skipping batch: 3391-3400 as it's already cached
# Skipping batch: 3401-3410 as it's already cached
# Skipping batch: 3411-3420 as it's already cached
# Skipping batch: 3421-3430 as it's already cached
# Skipping batch: 3431-3440 as it's already cached
# Skipping batch: 3441-3450 as it's already cached
# Skipping batch: 3451-3460 as it's already cached
# Skipping batch: 3461-3470 as it's already cached
# Skipping batch: 3471-3480 as it's already cached
# Skipping batch: 3481-3490 as it's already cached
# Skipping batch: 3491-3500 as it's already cached
# Skipping batch: 3501-3510 as it's already cached
# Skipping batch: 3511-3520 as it's already cached
# Skipping batch: 3521-3530 as it's already cached
# Skipping batch: 3531-3540 as it's already cached
# Skipping batch: 3541-3550 as it's already cached
# Skipping batch: 3551-3560 as it's already cached
# Skipping batch: 3561-3570 as it's already cached
# Skipping batch: 3571-3580 as it's already cached
# Skipping batch: 3581-3590 as it's already cached
# Skipping batch: 3591-3600 as it's already cached
# Skipping batch: 3601-3610 as it's already cached
# Skipping batch: 3611-3620 as it's already cached
# Skipping batch: 3621-3630 as it's already cached
# Skipping batch: 3631-3640 as it's already cached
# Skipping batch: 3641-3650 as it's already cached
# Skipping batch: 3651-3660 as it's already cached
# Skipping batch: 3661-3670 as it's already cached
# Skipping batch: 3671-3680 as it's already cached
# Skipping batch: 3681-3690 as it's already cached
# Skipping batch: 3691-3700 as it's already cached
# Skipping batch: 3701-3710 as it's already cached
# Skipping batch: 3711-3720 as it's already cached
# Skipping batch: 3721-3730 as it's already cached
# Skipping batch: 3731-3740 as it's already cached
# Skipping batch: 3741-3750 as it's already cached
# Skipping batch: 3751-3760 as it's already cached
# Skipping batch: 3761-3770 as it's already cached
# Skipping batch: 3771-3780 as it's already cached
# Skipping batch: 3781-3790 as it's already cached
# Skipping batch: 3791-3800 as it's already cached
# Skipping batch: 3801-3810 as it's already cached
# Skipping batch: 3811-3820 as it's already cached
# Skipping batch: 3821-3830 as it's already cached
# Skipping batch: 3831-3840 as it's already cached
# Skipping batch: 3841-3850 as it's already cached
# Skipping batch: 3851-3860 as it's already cached
# Skipping batch: 3861-3870 as it's already cached
# Skipping batch: 3871-3880 as it's already cached
# Skipping batch: 3881-3890 as it's already cached
# Skipping batch: 3891-3900 as it's already cached
# Skipping batch: 3901-3910 as it's already cached
# Skipping batch: 3911-3920 as it's already cached
# Skipping batch: 3921-3930 as it's already cached
# Skipping batch: 3931-3940 as it's already cached
# Skipping batch: 3941-3950 as it's already cached
# Skipping batch: 3951-3960 as it's already cached
# Skipping batch: 3961-3970 as it's already cached
# Skipping batch: 3971-3980 as it's already cached
# Skipping batch: 3981-3990 as it's already cached
# Skipping batch: 3991-4000 as it's already cached
# Skipping batch: 4001-4010 as it's already cached
# Skipping batch: 4011-4020 as it's already cached
# Skipping batch: 4021-4030 as it's already cached
# Skipping batch: 4031-4040 as it's already cached
# Skipping batch: 4041-4050 as it's already cached
# Skipping batch: 4051-4060 as it's already cached
# Skipping batch: 4061-4070 as it's already cached
# Skipping batch: 4071-4080 as it's already cached
# Skipping batch: 4081-4090 as it's already cached
# Skipping batch: 4091-4100 as it's already cached
# Skipping batch: 4101-4110 as it's already cached
# Skipping batch: 4111-4120 as it's already cached
# Skipping batch: 4121-4130 as it's already cached
# Skipping batch: 4131-4140 as it's already cached
# Skipping batch: 4141-4150 as it's already cached
# Skipping batch: 4151-4160 as it's already cached
# Skipping batch: 4161-4170 as it's already cached
# Skipping batch: 4171-4180 as it's already cached
# Skipping batch: 4181-4190 as it's already cached
# Skipping batch: 4191-4200 as it's already cached
# Skipping batch: 4201-4210 as it's already cached
# Skipping batch: 4211-4220 as it's already cached
# Skipping batch: 4221-4230 as it's already cached
# Skipping batch: 4231-4240 as it's already cached
# Skipping batch: 4241-4250 as it's already cached
# Skipping batch: 4251-4260 as it's already cached
# Skipping batch: 4261-4270 as it's already cached
# Skipping batch: 4271-4280 as it's already cached
# Skipping batch: 4281-4290 as it's already cached
# Skipping batch: 4291-4300 as it's already cached
# Skipping batch: 4301-4310 as it's already cached
# Skipping batch: 4311-4320 as it's already cached
# Skipping batch: 4321-4330 as it's already cached
# Skipping batch: 4331-4340 as it's already cached
# Skipping batch: 4341-4350 as it's already cached
# Skipping batch: 4351-4360 as it's already cached
# Skipping batch: 4361-4370 as it's already cached
# Skipping batch: 4371-4380 as it's already cached
# Skipping batch: 4381-4390 as it's already cached
# Skipping batch: 4391-4400 as it's already cached
# Skipping batch: 4401-4410 as it's already cached
# Skipping batch: 4411-4420 as it's already cached
# Skipping batch: 4421-4430 as it's already cached
# Skipping batch: 4431-4440 as it's already cached
# Skipping batch: 4441-4450 as it's already cached
# Skipping batch: 4451-4460 as it's already cached
# Skipping batch: 4461-4470 as it's already cached
# Skipping batch: 4471-4480 as it's already cached
# Skipping batch: 4481-4490 as it's already cached
# Skipping batch: 4491-4500 as it's already cached
# Skipping batch: 4501-4510 as it's already cached
# Skipping batch: 4511-4520 as it's already cached
# Skipping batch: 4521-4530 as it's already cached
# Skipping batch: 4531-4540 as it's already cached
# Skipping batch: 4541-4550 as it's already cached
# Skipping batch: 4551-4560 as it's already cached
# Skipping batch: 4561-4570 as it's already cached
# Skipping batch: 4571-4580 as it's already cached
# Skipping batch: 4581-4590 as it's already cached
# Skipping batch: 4591-4600 as it's already cached
# Skipping batch: 4601-4610 as it's already cached
# Skipping batch: 4611-4620 as it's already cached
# Skipping batch: 4621-4630 as it's already cached
# Skipping batch: 4631-4640 as it's already cached
# Skipping batch: 4641-4650 as it's already cached
# Skipping batch: 4651-4660 as it's already cached
# Skipping batch: 4661-4670 as it's already cached
# Skipping batch: 4671-4680 as it's already cached
# Skipping batch: 4681-4690 as it's already cached
# Skipping batch: 4691-4700 as it's already cached
# Skipping batch: 4701-4710 as it's already cached
# Skipping batch: 4711-4720 as it's already cached
# Skipping batch: 4721-4730 as it's already cached
# Skipping batch: 4731-4740 as it's already cached
# Skipping batch: 4741-4750 as it's already cached
# Skipping batch: 4751-4760 as it's already cached
# Skipping batch: 4761-4770 as it's already cached
# Skipping batch: 4771-4780 as it's already cached
# Skipping batch: 4781-4790 as it's already cached
# Skipping batch: 4791-4800 as it's already cached
# Skipping batch: 4801-4810 as it's already cached
# Skipping batch: 4811-4820 as it's already cached
# Skipping batch: 4821-4830 as it's already cached
# Skipping batch: 4831-4840 as it's already cached
# Skipping batch: 4841-4850 as it's already cached
# Skipping batch: 4851-4860 as it's already cached
# Skipping batch: 4861-4870 as it's already cached
# Skipping batch: 4871-4880 as it's already cached
# Skipping batch: 4881-4890 as it's already cached
# Skipping batch: 4891-4900 as it's already cached
# Skipping batch: 4901-4910 as it's already cached
# Skipping batch: 4911-4920 as it's already cached
# Skipping batch: 4921-4930 as it's already cached
# Skipping batch: 4931-4940 as it's already cached
# Skipping batch: 4941-4950 as it's already cached
# Skipping batch: 4951-4960 as it's already cached
# Skipping batch: 4961-4970 as it's already cached
# Skipping batch: 4971-4980 as it's already cached
# Skipping batch: 4981-4990 as it's already cached
# Skipping batch: 4991-5000 as it's already cached
# Skipping batch: 5001-5010 as it's already cached
# Skipping batch: 5011-5020 as it's already cached
# Skipping batch: 5021-5030 as it's already cached
# Skipping batch: 5031-5040 as it's already cached
# Skipping batch: 5041-5050 as it's already cached
# Skipping batch: 5051-5060 as it's already cached
# Skipping batch: 5061-5070 as it's already cached
# Skipping batch: 5071-5080 as it's already cached
# Skipping batch: 5081-5090 as it's already cached
# Skipping batch: 5091-5100 as it's already cached
# Skipping batch: 5101-5110 as it's already cached
# Skipping batch: 5111-5120 as it's already cached
# Skipping batch: 5121-5130 as it's already cached
# Skipping batch: 5131-5140 as it's already cached
# Skipping batch: 5141-5150 as it's already cached
# Skipping batch: 5151-5160 as it's already cached
# Skipping batch: 5161-5170 as it's already cached
# Skipping batch: 5171-5180 as it's already cached
# Skipping batch: 5181-5190 as it's already cached
# Skipping batch: 5191-5200 as it's already cached
# Skipping batch: 5201-5210 as it's already cached
# Skipping batch: 5211-5220 as it's already cached
# Skipping batch: 5221-5230 as it's already cached
# Skipping batch: 5231-5240 as it's already cached
# Skipping batch: 5241-5250 as it's already cached
# Skipping batch: 5251-5260 as it's already cached
# Skipping batch: 5261-5270 as it's already cached
# Skipping batch: 5271-5280 as it's already cached
# Skipping batch: 5281-5290 as it's already cached
# Skipping batch: 5291-5300 as it's already cached
# Skipping batch: 5301-5310 as it's already cached
# Skipping batch: 5311-5320 as it's already cached
# Skipping batch: 5321-5330 as it's already cached
# Skipping batch: 5331-5340 as it's already cached
# Skipping batch: 5341-5350 as it's already cached
# Skipping batch: 5351-5360 as it's already cached
# Skipping batch: 5361-5370 as it's already cached
# Skipping batch: 5371-5380 as it's already cached
# Skipping batch: 5381-5390 as it's already cached
# Skipping batch: 5391-5400 as it's already cached
# Skipping batch: 5401-5410 as it's already cached
# Skipping batch: 5411-5420 as it's already cached
# Skipping batch: 5421-5430 as it's already cached
# Skipping batch: 5431-5440 as it's already cached
# Skipping batch: 5441-5450 as it's already cached
# Skipping batch: 5451-5460 as it's already cached
# Skipping batch: 5461-5470 as it's already cached
# Skipping batch: 5471-5480 as it's already cached
# Skipping batch: 5481-5490 as it's already cached
# Skipping batch: 5491-5500 as it's already cached
# Skipping batch: 5501-5510 as it's already cached
# Skipping batch: 5511-5520 as it's already cached
# Skipping batch: 5521-5530 as it's already cached
# Skipping batch: 5531-5540 as it's already cached
# Skipping batch: 5541-5550 as it's already cached
# Skipping batch: 5551-5560 as it's already cached
# Skipping batch: 5561-5570 as it's already cached
# Skipping batch: 5571-5580 as it's already cached
# Skipping batch: 5581-5590 as it's already cached
# Skipping batch: 5591-5600 as it's already cached
# Skipping batch: 5601-5610 as it's already cached
# Skipping batch: 5611-5620 as it's already cached
# Skipping batch: 5621-5630 as it's already cached
# Skipping batch: 5631-5640 as it's already cached
# Skipping batch: 5641-5650 as it's already cached
# Skipping batch: 5651-5660 as it's already cached
# Skipping batch: 5661-5670 as it's already cached
# Skipping batch: 5671-5680 as it's already cached
# Skipping batch: 5681-5690 as it's already cached
# Skipping batch: 5691-5700 as it's already cached
# Skipping batch: 5701-5710 as it's already cached
# Skipping batch: 5711-5720 as it's already cached
# Skipping batch: 5721-5730 as it's already cached
# Skipping batch: 5731-5740 as it's already cached
# Skipping batch: 5741-5750 as it's already cached
# Skipping batch: 5751-5760 as it's already cached
# Skipping batch: 5761-5770 as it's already cached
# Skipping batch: 5771-5780 as it's already cached
# Skipping batch: 5781-5790 as it's already cached
# Skipping batch: 5791-5800 as it's already cached
# Skipping batch: 5801-5810 as it's already cached
# Skipping batch: 5811-5820 as it's already cached
# Skipping batch: 5821-5830 as it's already cached
# Skipping batch: 5831-5840 as it's already cached
# Skipping batch: 5841-5850 as it's already cached
# Skipping batch: 5851-5860 as it's already cached
# Skipping batch: 5861-5870 as it's already cached
# Skipping batch: 5871-5880 as it's already cached
# Skipping batch: 5881-5890 as it's already cached
# Skipping batch: 5891-5900 as it's already cached
# Skipping batch: 5901-5910 as it's already cached
# Skipping batch: 5911-5920 as it's already cached
# Skipping batch: 5921-5930 as it's already cached
# Skipping batch: 5931-5940 as it's already cached
# Skipping batch: 5941-5950 as it's already cached
# Skipping batch: 5951-5960 as it's already cached
# Skipping batch: 5961-5970 as it's already cached
# Skipping batch: 5971-5980 as it's already cached
# Skipping batch: 5981-5990 as it's already cached
# Skipping batch: 5991-6000 as it's already cached
# Skipping batch: 6001-6010 as it's already cached
# Skipping batch: 6011-6020 as it's already cached
# Skipping batch: 6021-6030 as it's already cached
# Skipping batch: 6031-6040 as it's already cached
# Skipping batch: 6041-6050 as it's already cached
# Skipping batch: 6051-6060 as it's already cached
# Skipping batch: 6061-6070 as it's already cached
# Skipping batch: 6071-6080 as it's already cached
# Skipping batch: 6081-6090 as it's already cached
# Skipping batch: 6091-6100 as it's already cached
# Skipping batch: 6101-6110 as it's already cached
# Skipping batch: 6111-6120 as it's already cached
# Skipping batch: 6121-6130 as it's already cached
# Skipping batch: 6131-6140 as it's already cached
# Skipping batch: 6141-6150 as it's already cached
# Skipping batch: 6151-6160 as it's already cached
# Skipping batch: 6161-6170 as it's already cached
# Skipping batch: 6171-6180 as it's already cached
# Skipping batch: 6181-6190 as it's already cached
# Skipping batch: 6191-6200 as it's already cached
# Skipping batch: 6201-6210 as it's already cached
# Skipping batch: 6211-6220 as it's already cached
# Skipping batch: 6221-6230 as it's already cached
# Skipping batch: 6231-6240 as it's already cached
# Skipping batch: 6241-6250 as it's already cached
# Skipping batch: 6251-6260 as it's already cached
# Skipping batch: 6261-6270 as it's already cached
# Skipping batch: 6271-6280 as it's already cached
# Skipping batch: 6281-6290 as it's already cached
# Skipping batch: 6291-6300 as it's already cached
# Skipping batch: 6301-6310 as it's already cached
# Skipping batch: 6311-6320 as it's already cached
# Skipping batch: 6321-6330 as it's already cached
# Skipping batch: 6331-6340 as it's already cached
# Skipping batch: 6341-6350 as it's already cached
# Skipping batch: 6351-6360 as it's already cached
# Skipping batch: 6361-6370 as it's already cached
# Skipping batch: 6371-6380 as it's already cached
# Skipping batch: 6381-6390 as it's already cached
# Skipping batch: 6391-6400 as it's already cached
# Skipping batch: 6401-6410 as it's already cached
# Skipping batch: 6411-6420 as it's already cached
# Skipping batch: 6421-6430 as it's already cached
# Skipping batch: 6431-6440 as it's already cached
# Skipping batch: 6441-6450 as it's already cached
# Skipping batch: 6451-6460 as it's already cached
# Skipping batch: 6461-6470 as it's already cached
# Skipping batch: 6471-6480 as it's already cached
# Skipping batch: 6481-6490 as it's already cached
# Skipping batch: 6491-6500 as it's already cached
# Skipping batch: 6501-6510 as it's already cached
# Skipping batch: 6511-6520 as it's already cached
# Skipping batch: 6521-6530 as it's already cached
# Skipping batch: 6531-6540 as it's already cached
# Skipping batch: 6541-6550 as it's already cached
# Skipping batch: 6551-6560 as it's already cached
# Skipping batch: 6561-6570 as it's already cached
# Skipping batch: 6571-6580 as it's already cached
# Skipping batch: 6581-6590 as it's already cached
# Skipping batch: 6591-6600 as it's already cached
# Skipping batch: 6601-6610 as it's already cached
# Skipping batch: 6611-6620 as it's already cached
# Skipping batch: 6621-6630 as it's already cached
# Skipping batch: 6631-6640 as it's already cached
# Skipping batch: 6641-6650 as it's already cached
# Skipping batch: 6651-6660 as it's already cached
# Skipping batch: 6661-6670 as it's already cached
# Skipping batch: 6671-6680 as it's already cached
# Skipping batch: 6681-6690 as it's already cached
# Skipping batch: 6691-6700 as it's already cached
# Skipping batch: 6701-6710 as it's already cached
# Skipping batch: 6711-6720 as it's already cached
# Skipping batch: 6721-6730 as it's already cached
# Skipping batch: 6731-6740 as it's already cached
# Skipping batch: 6741-6750 as it's already cached
# Skipping batch: 6751-6760 as it's already cached
# Skipping batch: 6761-6770 as it's already cached
# Skipping batch: 6771-6780 as it's already cached
# Skipping batch: 6781-6790 as it's already cached
# Skipping batch: 6791-6800 as it's already cached
# Skipping batch: 6801-6810 as it's already cached
# Skipping batch: 6811-6820 as it's already cached
# Skipping batch: 6821-6830 as it's already cached
# Skipping batch: 6831-6840 as it's already cached
# Skipping batch: 6841-6850 as it's already cached
# Skipping batch: 6851-6860 as it's already cached
# Skipping batch: 6861-6870 as it's already cached
# Skipping batch: 6871-6880 as it's already cached
# Skipping batch: 6881-6890 as it's already cached
# Skipping batch: 6891-6900 as it's already cached
# Skipping batch: 6901-6910 as it's already cached
# Skipping batch: 6911-6920 as it's already cached
# Skipping batch: 6921-6930 as it's already cached
# Skipping batch: 6931-6940 as it's already cached
# Skipping batch: 6941-6950 as it's already cached
# Skipping batch: 6951-6960 as it's already cached
# Skipping batch: 6961-6970 as it's already cached
# Skipping batch: 6971-6980 as it's already cached
# Skipping batch: 6981-6990 as it's already cached
# Skipping batch: 6991-7000 as it's already cached
# Skipping batch: 7001-7010 as it's already cached
# Skipping batch: 7011-7020 as it's already cached
# Skipping batch: 7021-7030 as it's already cached
# Skipping batch: 7031-7040 as it's already cached
# Skipping batch: 7041-7050 as it's already cached
# Skipping batch: 7051-7060 as it's already cached
# Skipping batch: 7061-7070 as it's already cached
# Skipping batch: 7071-7080 as it's already cached
# Skipping batch: 7081-7090 as it's already cached
# Skipping batch: 7091-7100 as it's already cached
# Skipping batch: 7101-7110 as it's already cached
# Skipping batch: 7111-7120 as it's already cached
# Skipping batch: 7121-7130 as it's already cached
# Skipping batch: 7131-7140 as it's already cached
# Skipping batch: 7141-7150 as it's already cached
# Skipping batch: 7151-7160 as it's already cached
# Skipping batch: 7161-7170 as it's already cached
# Skipping batch: 7171-7180 as it's already cached
# Skipping batch: 7181-7190 as it's already cached
# Skipping batch: 7191-7200 as it's already cached
# Skipping batch: 7201-7210 as it's already cached
# Skipping batch: 7211-7220 as it's already cached
# Skipping batch: 7221-7230 as it's already cached
# Skipping batch: 7231-7240 as it's already cached
# Skipping batch: 7241-7250 as it's already cached
# Skipping batch: 7251-7260 as it's already cached
# Skipping batch: 7261-7270 as it's already cached
# Skipping batch: 7271-7280 as it's already cached
# Skipping batch: 7281-7290 as it's already cached
# Skipping batch: 7291-7300 as it's already cached
# Skipping batch: 7301-7310 as it's already cached
# Skipping batch: 7311-7320 as it's already cached
# Skipping batch: 7321-7330 as it's already cached
# Skipping batch: 7331-7340 as it's already cached
# Skipping batch: 7341-7350 as it's already cached
# Skipping batch: 7351-7360 as it's already cached
# Skipping batch: 7361-7370 as it's already cached
# Skipping batch: 7371-7380 as it's already cached
# Skipping batch: 7381-7390 as it's already cached
# Skipping batch: 7391-7400 as it's already cached
# Skipping batch: 7401-7410 as it's already cached
# Skipping batch: 7411-7420 as it's already cached
# Skipping batch: 7421-7430 as it's already cached
# Skipping batch: 7431-7440 as it's already cached
# Skipping batch: 7441-7450 as it's already cached
# Skipping batch: 7451-7460 as it's already cached
# Skipping batch: 7461-7470 as it's already cached
# Skipping batch: 7471-7480 as it's already cached
# Skipping batch: 7481-7490 as it's already cached
# Skipping batch: 7491-7500 as it's already cached
# Skipping batch: 7501-7510 as it's already cached
# Skipping batch: 7511-7520 as it's already cached
# Skipping batch: 7521-7530 as it's already cached
# Skipping batch: 7531-7540 as it's already cached
# Skipping batch: 7541-7550 as it's already cached
# Skipping batch: 7551-7560 as it's already cached
# Skipping batch: 7561-7570 as it's already cached
# Skipping batch: 7571-7580 as it's already cached
# Skipping batch: 7581-7590 as it's already cached
# Skipping batch: 7591-7600 as it's already cached
# Skipping batch: 7601-7610 as it's already cached
# Skipping batch: 7611-7620 as it's already cached
# Skipping batch: 7621-7630 as it's already cached
# Skipping batch: 7631-7640 as it's already cached
# Skipping batch: 7641-7650 as it's already cached
# Skipping batch: 7651-7660 as it's already cached
# Skipping batch: 7661-7670 as it's already cached
# Skipping batch: 7671-7680 as it's already cached
# Skipping batch: 7681-7690 as it's already cached
# Skipping batch: 7691-7700 as it's already cached
# Skipping batch: 7701-7710 as it's already cached
# Skipping batch: 7711-7720 as it's already cached
# Skipping batch: 7721-7730 as it's already cached
# Skipping batch: 7731-7740 as it's already cached
# Skipping batch: 7741-7750 as it's already cached
# Skipping batch: 7751-7760 as it's already cached
# Skipping batch: 7761-7770 as it's already cached
# Skipping batch: 7771-7780 as it's already cached
# Skipping batch: 7781-7790 as it's already cached
# Skipping batch: 7791-7800 as it's already cached
# Skipping batch: 7801-7810 as it's already cached
# Skipping batch: 7811-7820 as it's already cached
# Skipping batch: 7821-7830 as it's already cached
# Skipping batch: 7831-7840 as it's already cached
# Skipping batch: 7841-7850 as it's already cached
# Skipping batch: 7851-7860 as it's already cached
# Skipping batch: 7861-7870 as it's already cached
# Skipping batch: 7871-7880 as it's already cached
# Skipping batch: 7881-7890 as it's already cached
# Skipping batch: 7891-7900 as it's already cached
# Skipping batch: 7901-7910 as it's already cached
# Skipping batch: 7911-7920 as it's already cached
# Skipping batch: 7921-7930 as it's already cached
# Skipping batch: 7931-7940 as it's already cached
# Skipping batch: 7941-7950 as it's already cached
# Skipping batch: 7951-7960 as it's already cached
# Skipping batch: 7961-7970 as it's already cached
# Skipping batch: 7971-7980 as it's already cached
# Skipping batch: 7981-7990 as it's already cached
# Skipping batch: 7991-8000 as it's already cached
# Skipping batch: 8001-8010 as it's already cached
# Skipping batch: 8011-8020 as it's already cached
# Skipping batch: 8021-8030 as it's already cached
# Skipping batch: 8031-8040 as it's already cached
# Skipping batch: 8041-8050 as it's already cached
# Skipping batch: 8051-8060 as it's already cached
# Skipping batch: 8061-8070 as it's already cached
# Skipping batch: 8071-8080 as it's already cached
# Skipping batch: 8081-8090 as it's already cached
# Skipping batch: 8091-8100 as it's already cached
# Skipping batch: 8101-8110 as it's already cached
# Skipping batch: 8111-8120 as it's already cached
# Skipping batch: 8121-8130 as it's already cached
# Skipping batch: 8131-8140 as it's already cached
# Skipping batch: 8141-8150 as it's already cached
# Skipping batch: 8151-8160 as it's already cached
# Skipping batch: 8161-8170 as it's already cached
# Skipping batch: 8171-8180 as it's already cached
# Skipping batch: 8181-8190 as it's already cached
# Skipping batch: 8191-8200 as it's already cached
# Skipping batch: 8201-8210 as it's already cached
# Skipping batch: 8211-8220 as it's already cached
# Skipping batch: 8221-8230 as it's already cached
# Skipping batch: 8231-8240 as it's already cached
# Skipping batch: 8241-8250 as it's already cached
# Skipping batch: 8251-8260 as it's already cached
# Skipping batch: 8261-8270 as it's already cached
# Skipping batch: 8271-8280 as it's already cached
# Skipping batch: 8281-8290 as it's already cached
# Skipping batch: 8291-8300 as it's already cached
# Skipping batch: 8301-8310 as it's already cached
# Skipping batch: 8311-8320 as it's already cached
# Skipping batch: 8321-8330 as it's already cached
# Skipping batch: 8331-8340 as it's already cached
# Skipping batch: 8341-8350 as it's already cached
# Skipping batch: 8351-8360 as it's already cached
# Skipping batch: 8361-8370 as it's already cached
# Skipping batch: 8371-8380 as it's already cached
# Skipping batch: 8381-8390 as it's already cached
# Skipping batch: 8391-8400 as it's already cached
# Skipping batch: 8401-8410 as it's already cached
# Skipping batch: 8411-8420 as it's already cached
# Skipping batch: 8421-8430 as it's already cached
# Skipping batch: 8431-8440 as it's already cached
# Skipping batch: 8441-8450 as it's already cached
# Skipping batch: 8451-8460 as it's already cached
# Skipping batch: 8461-8470 as it's already cached
# Skipping batch: 8471-8480 as it's already cached
# Skipping batch: 8481-8490 as it's already cached
# Skipping batch: 8491-8500 as it's already cached
# Skipping batch: 8501-8510 as it's already cached
# Skipping batch: 8511-8520 as it's already cached
# Skipping batch: 8521-8530 as it's already cached
# Skipping batch: 8531-8540 as it's already cached
# Skipping batch: 8541-8550 as it's already cached
# Skipping batch: 8551-8560 as it's already cached
# Skipping batch: 8561-8570 as it's already cached
# Skipping batch: 8571-8580 as it's already cached
# Skipping batch: 8581-8590 as it's already cached
# Skipping batch: 8591-8600 as it's already cached
# Skipping batch: 8601-8610 as it's already cached
# Skipping batch: 8611-8620 as it's already cached
# Skipping batch: 8621-8630 as it's already cached
# Skipping batch: 8631-8640 as it's already cached
# Skipping batch: 8641-8650 as it's already cached
# Skipping batch: 8651-8660 as it's already cached
# Skipping batch: 8661-8670 as it's already cached
# Skipping batch: 8671-8680 as it's already cached
# Skipping batch: 8681-8690 as it's already cached
# Skipping batch: 8691-8700 as it's already cached
# Skipping batch: 8701-8710 as it's already cached
# Skipping batch: 8711-8720 as it's already cached
# Skipping batch: 8721-8730 as it's already cached
# Skipping batch: 8731-8740 as it's already cached
# Skipping batch: 8741-8750 as it's already cached
# Skipping batch: 8751-8760 as it's already cached
# Skipping batch: 8761-8770 as it's already cached
# Skipping batch: 8771-8780 as it's already cached
# Skipping batch: 8781-8790 as it's already cached
# Skipping batch: 8791-8800 as it's already cached
# Skipping batch: 8801-8810 as it's already cached
# Skipping batch: 8811-8820 as it's already cached
# Skipping batch: 8821-8830 as it's already cached
# Skipping batch: 8831-8840 as it's already cached
# Skipping batch: 8841-8850 as it's already cached
# Skipping batch: 8851-8860 as it's already cached
# Skipping batch: 8861-8870 as it's already cached
# Skipping batch: 8871-8880 as it's already cached
# Skipping batch: 8881-8890 as it's already cached
# Skipping batch: 8891-8900 as it's already cached
# Skipping batch: 8901-8910 as it's already cached
# Skipping batch: 8911-8920 as it's already cached
# Skipping batch: 8921-8930 as it's already cached
# Skipping batch: 8931-8940 as it's already cached
# Skipping batch: 8941-8950 as it's already cached
# Skipping batch: 8951-8960 as it's already cached
# Skipping batch: 8961-8970 as it's already cached
# Skipping batch: 8971-8980 as it's already cached
# Skipping batch: 8981-8990 as it's already cached
# Skipping batch: 8991-9000 as it's already cached
# Skipping batch: 9001-9010 as it's already cached
# Skipping batch: 9011-9020 as it's already cached
# Skipping batch: 9021-9030 as it's already cached
# Skipping batch: 9031-9040 as it's already cached
# Skipping batch: 9041-9050 as it's already cached
# Skipping batch: 9051-9060 as it's already cached
# Skipping batch: 9061-9070 as it's already cached
# Skipping batch: 9071-9080 as it's already cached
# Skipping batch: 9081-9090 as it's already cached
# Skipping batch: 9091-9100 as it's already cached
# Skipping batch: 9101-9110 as it's already cached
# Skipping batch: 9111-9120 as it's already cached
# Skipping batch: 9121-9130 as it's already cached
# Skipping batch: 9131-9140 as it's already cached
# Skipping batch: 9141-9150 as it's already cached
# Skipping batch: 9151-9160 as it's already cached
# Skipping batch: 9161-9170 as it's already cached
# Skipping batch: 9171-9180 as it's already cached
# Skipping batch: 9181-9190 as it's already cached
# Skipping batch: 9191-9200 as it's already cached
# Skipping batch: 9201-9210 as it's already cached
# Skipping batch: 9211-9220 as it's already cached
# Skipping batch: 9221-9230 as it's already cached
# Skipping batch: 9231-9240 as it's already cached
# Skipping batch: 9241-9250 as it's already cached
# Skipping batch: 9251-9260 as it's already cached
# Skipping batch: 9261-9270 as it's already cached
# Skipping batch: 9271-9280 as it's already cached
# Skipping batch: 9281-9290 as it's already cached
# Skipping batch: 9291-9300 as it's already cached
# Skipping batch: 9301-9310 as it's already cached
# Skipping batch: 9311-9320 as it's already cached
# Skipping batch: 9321-9330 as it's already cached
# Skipping batch: 9331-9340 as it's already cached
# Skipping batch: 9341-9350 as it's already cached
# Skipping batch: 9351-9360 as it's already cached
# Skipping batch: 9361-9370 as it's already cached
# Skipping batch: 9371-9380 as it's already cached
# Skipping batch: 9381-9390 as it's already cached
# Skipping batch: 9391-9400 as it's already cached
# Requesting batch: 9401-9410 out of 10000
# Requesting batch: 9411-9420 out of 10000
# Requesting batch: 9421-9430 out of 10000
# Requesting batch: 9431-9440 out of 10000
# Requesting batch: 9441-9450 out of 10000
# Requesting batch: 9451-9460 out of 10000
# Requesting batch: 9461-9470 out of 10000
# Requesting batch: 9471-9480 out of 10000
# Requesting batch: 9481-9490 out of 10000
# Requesting batch: 9491-9500 out of 10000
# Requesting batch: 9501-9510 out of 10000
# Requesting batch: 9511-9520 out of 10000
# Requesting batch: 9521-9530 out of 10000
# Requesting batch: 9531-9540 out of 10000
# Requesting batch: 9541-9550 out of 10000
# Requesting batch: 9551-9560 out of 10000
# Requesting batch: 9561-9570 out of 10000
# Requesting batch: 9571-9580 out of 10000
# Requesting batch: 9581-9590 out of 10000
# Requesting batch: 9591-9600 out of 10000
# Requesting batch: 9601-9610 out of 10000
# Requesting batch: 9611-9620 out of 10000
# Requesting batch: 9621-9630 out of 10000
# Requesting batch: 9631-9640 out of 10000
# Requesting batch: 9641-9650 out of 10000
# Requesting batch: 9651-9660 out of 10000
# Requesting batch: 9661-9670 out of 10000
# Requesting batch: 9671-9680 out of 10000
# Requesting batch: 9681-9690 out of 10000
# Requesting batch: 9691-9700 out of 10000
# Requesting batch: 9701-9710 out of 10000
# Requesting batch: 9711-9720 out of 10000
# Requesting batch: 9721-9730 out of 10000
# Requesting batch: 9731-9740 out of 10000
# Requesting batch: 9741-9750 out of 10000
# Requesting batch: 9751-9760 out of 10000
# Failed to request batch: 9751-9760 on attempt 1. Failed to fetch data: 504
# Requesting batch: 9761-9770 out of 10000
# Requesting batch: 9771-9780 out of 10000
# Requesting batch: 9781-9790 out of 10000
# Requesting batch: 9791-9800 out of 10000
# Requesting batch: 9801-9810 out of 10000
# Requesting batch: 9811-9820 out of 10000
# Requesting batch: 9821-9830 out of 10000
# Requesting batch: 9831-9840 out of 10000
# Requesting batch: 9841-9850 out of 10000
# Requesting batch: 9851-9860 out of 10000
# Requesting batch: 9861-9870 out of 10000
# Requesting batch: 9871-9880 out of 10000
# Requesting batch: 9881-9890 out of 10000
# Requesting batch: 9891-9900 out of 10000
# Requesting batch: 9901-9910 out of 10000
# Requesting batch: 9911-9920 out of 10000
# Requesting batch: 9921-9930 out of 10000
# Requesting batch: 9931-9940 out of 10000
# Requesting batch: 9941-9950 out of 10000
# Requesting batch: 9951-9960 out of 10000
# Requesting batch: 9961-9970 out of 10000
# Requesting batch: 9971-9980 out of 10000
# Requesting batch: 9981-9990 out of 10000
# Requesting batch: 9991-10000 out of 10000

# %%
results = [result['domain'] for result in read_json()]
print(len(results))

for domain in domains:
    if domain not in results:
        print(f"Domain {domain} not found in results")
        break
# Out:
# 10000
